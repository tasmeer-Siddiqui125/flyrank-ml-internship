# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/tasmeer-Siddiqui125/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*
#
#
# I chose the classification lane because I want to investigate whether content pages can be classified into higher- and lower-engagement groups using the characteristics available in the dataset. The dataset contains variables such as `avg_position`, `ctr`, `content_age_days`, `trend_direction`, and `engagement_rate`. Since there is no existing high/low engagement target, I will need to define and justify the target before training a model. This direction gives me a specific decision to investigate rather than simply building a model without a clear purpose.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*
#
#
# **Decision:**
#
# Which content pages should be considered higher- or lower-engagement based on their available characteristics?
#
# **Who acts:**
#
# A content or SEO team could use the classification results to identify pages that may need further investigation or different content strategies.
#
# **Cost of a wrong call:**
#
# A false recommendation could cause a team to spend time changing pages that do not need intervention or overlook pages that could benefit from attention.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd
import numpy as np


url = "https://raw.githubusercontent.com/tasmeer-Siddiqui125/flyrank-ml-internship/refs/heads/main/data/raw/content_refresh_anonymized.csv"
df = pd.read_csv(url)
df
# Out:
#                  content_id          client_id  search_volume  competition  \
# 0      content_304f48230142  client_f369cb89fc           10.0         0.67
# 1      content_a1fb4e703a9e  client_4e07408562           90.0         0.01
# 2      content_9aa793d4d895  client_7f2253d7e2            0.0         0.00
# 3      content_331d6c4de07b  client_19581e27de           10.0         0.00
# 4      content_d99b7a2d90ca  client_3fdba35f04            0.0         0.00
# ...                     ...                ...            ...          ...
# 29995  content_c322796023c8  client_e29c9c180c           10.0         0.05
# 29996  content_526572edb3fa  client_7f2253d7e2            0.0         0.00
# 29997  content_38112bdd0c6e  client_349c41201b           10.0         1.00
# 29998  content_ab26273a7e7a  client_19581e27de           10.0         0.00
# 29999  content_887020f20b5e  client_6208ef0f77            0.0         0.00
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 44 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   content_id              30000 non-null  object
#  1   client_id               30000 non-null  object
#  2   search_volume           27532 non-null  float64
#  3   competition             27532 non-null  float64
#  4   competition_level       27390 non-null  object
#  5   cpc                     27532 non-null  float64
#  6   content_type            30000 non-null  object
#  7   main_intent             27626 non-null  object
#  8   word_count              22301 non-null  float64
#  9   char_count              22301 non-null  float64
#  10  provider_used           8562 non-null   object
#  11  model_used              24267 non-null  object
#  12  impressions_90d         30000 non-null  int64
#  13  clicks_90d              30000 non-null  int64
# ...

# %%
df.shape
# Out:
# (30000, 44)

# %%
df.columns.tolist()
# Out:
# ['content_id',
#  'client_id',
#  'search_volume',
#  'competition',
#  'competition_level',
#  'cpc',
#  'content_type',
#  'main_intent',
#  'word_count',
#  'char_count',
#  'provider_used',
#  'model_used',
#  'impressions_90d',
#  'clicks_90d',
#  'pageviews_90d',
#  'sessions_90d',
#  'users_90d',
#  'engaged_sessions_90d',
#  'ai_sessions_90d',
#  'scroll_events_90d',
#  'days_with_impressions',
#  'days_with_sessions',
#  'impressions_last_30d',
#  'clicks_last_30d',
#  'sessions_last_30d',
#  'impressions_prev_30d',
#  'clicks_prev_30d',
#  'sessions_prev_30d',
#  'content_age_days',
#  'age_tier',
#  'age_tier_order',
#  'days_since_last_update',
#  'freshness_tier',
#  'word_count_tier',
#  'char_count_tier',
#  'ctr',
#  'avg_position',
#  'engagement_rate',
#  'scroll_rate',
#  'ai_traffic_pct',
#  'impression_tier',
#  'position_tier',
#  'trend_direction',
#  'trend_pct']

# %%
df.describe()
# Out:
#        search_volume   competition           cpc    word_count     char_count  \
# count   27532.000000  27532.000000  27532.000000  22301.000000   22301.000000
# mean      158.882391      0.146954      0.485342   3107.760325   20665.277835
# std      1518.270825      0.285241      2.101560   1452.382598   10115.344042
# min         0.000000      0.000000      0.000000      8.000000      40.000000
# 25%         0.000000      0.000000      0.000000   2413.000000   15644.000000
# 50%        10.000000      0.000000      0.000000   2877.000000   19116.000000
# 75%        20.000000      0.130000      0.000000   3666.000000   24011.000000
# max     74000.000000      1.000000    100.360000   9546.000000  111158.000000
#
#        impressions_90d    clicks_90d  pageviews_90d  sessions_90d  \
# count     30000.000000  30000.000000   30000.000000  30000.000000
# mean       5200.366300     16.097333      49.942467     37.066633
# std       16838.019547     75.076958     152.101430    107.069131
# ...

# %%
print("Number of content records:", len(df))
print("Average content age (days):", round(df["content_age_days"].mean(), 2))
print("Average engagement rate:", round(df["engagement_rate"].mean(), 2))
# Out:
# Number of content records: 30000
# Average content age (days): 256.17
# Average engagement rate: 2.53

# %%
print("Content records:", len(df))
print("Content age range:", df["content_age_days"].min(), "to", df["content_age_days"].max())
print("Engagement rate range:", df["engagement_rate"].min(), "to", df["engagement_rate"].max())
# Out:
# Content records: 30000
# Content age range: 90 to 564
# Engagement rate range: 0.0 to 100.0

# %% [markdown]
# The starter dataset contains **30,000 content records.** Content age ranges from **90 to 564 days,** while engagement rate ranges from **0.0 to 100.0.** This variation suggests that the dataset contains pages with substantially different characteristics, making it worth investigating whether unsupervised clustering can identify meaningful content archetypes. These numbers do not establish that useful clusters exist; they only provide an initial reason to investigate the possibility.

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*
#
#
# **What I can claim:**
# My analysis can evaluate whether the available features provide useful information for distinguishing higher- and lower-engagement content. The results can provide directional, decision-support information about which pages may belong to each engagement group.
#
# **What I cannot claim:**
# The model will not prove that any feature causes higher engagement, and it will not prove how Google's ranking algorithm works or predict Google's decisions. The results will only describe performance on the available dataset and should be evaluated using appropriate classification metrics.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
# **Self-check:** I have selected the classification lane and defined a specific question around distinguishing higher- and lower-engagement content. I identified the decision, the potential user of the results, and the cost of a wrong recommendation. I also used real numbers from the starter dataset to justify investigating this direction. I will treat the model's results as evidence for decision support rather than causal proof or a prediction of Google's algorithm
# Before you submit, confirm each line honestly:
#
# - [✓] Every section above is filled — markdown thinking AND the code that backs it
# - [✓] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [✓] No client names, URLs, or private queries anywhere
# - [✓] My claims use careful words: observed, measured, directional, decision-support
# - [✓] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
