# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/tasmeer-Siddiqui125/flyrank-ml-internship/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*
#
# My lane: **Classification**
#
# I am framing this project as a binary classification problem. The goal is to classify content pages into **higher**- and **lower-engagement** groups using characteristics available in the dataset, such as `avg_position`, `ctr`, `content_age_days`, and `trend_direction`. The classification target will be created from `engagement_rate`, since the starter dataset does not provide an existing high/low engagement target.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*
#
# Target: **Engagement level**
#
# The proposed target is a binary engagement-level label derived from `engagement_rate`. Each content page would be assigned to either a **higher-engagement** or **lower-engagement** class based on a threshold that will be selected after examining the distribution of `engagement_rate`.
#
# I have not fixed the threshold yet because I want the choice to be supported by the data rather than choosing an arbitrary cutoff.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*
#
# Success metric: **F1-score**
#
# I will use F1-score as the primary evaluation metric because the classification task involves identifying **higher-** and **lower-engagement** content, where both false positives and false negatives matter. I will also report accuracy, precision, and recall to understand the model's performance from different perspectives.
#
# A useful model should perform better than a simple baseline and should provide reasonably balanced performance between the two classes.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd

df = pd.read_csv("https://raw.githubusercontent.com/tasmeer-Siddiqui125/flyrank-ml-internship/refs/heads/main/data/raw/content_refresh_anonymized.csv")

df.head()
# Out:
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
# 1  content_a1fb4e703a9e  client_4e07408562           90.0         0.01
# 2  content_9aa793d4d895  client_7f2253d7e2            0.0         0.00
# 3  content_331d6c4de07b  client_19581e27de           10.0         0.00
# 4  content_d99b7a2d90ca  client_3fdba35f04            0.0         0.00
#
#   competition_level   cpc     content_type    main_intent  word_count  \
# 0              HIGH  2.05  keyword article  transactional      3221.0
# 1               LOW  0.05  keyword article  informational      2481.0
# 2               LOW  0.00  keyword article  informational      3515.0
# 3               LOW  0.00  keyword article     commercial         NaN
# 4               LOW  0.00  keyword article  informational      2803.0
#
#    char_count  ... char_count_tier   ctr  avg_position  engagement_rate  \
# ...

# %%
threshold = df["engagement_rate"].median()

df["engagement_level"] = (
    df["engagement_rate"] >= threshold
).astype(int)

df[
    ["content_id", "engagement_rate", "engagement_level"]
].head(10)
# Out:
#              content_id  engagement_rate  engagement_level
# 0  content_304f48230142             5.88                 1
# 1  content_a1fb4e703a9e             0.00                 1
# 2  content_9aa793d4d895             0.00                 1
# 3  content_331d6c4de07b             1.28                 1
# 4  content_d99b7a2d90ca             0.00                 1
# 5  content_d4084a4bc775             0.00                 1
# 6  content_9a34b442b552             0.00                 1
# 7  content_a63219c6e95a             3.57                 1
# 8  content_5e6c160719bc             5.88                 1
# 9  content_c27558df2b0c             0.00                 1

# %%
df["engagement_level"].value_counts()
# Out:
# engagement_level
# 1    30000
# Name: count, dtype: int64

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %% [markdown]
# A fixed rule would use a single manually chosen condition, such as classifying content based only on one feature or one threshold. However, engagement may relate to several characteristics at the same time, including position, click-through rate, content age, and trend direction.
#
# ML can evaluate combinations and interactions among multiple features and learn patterns from historical examples instead of relying on one manually selected rule. I will still compare the model against a simple baseline to determine whether the added complexity is justified.
#
# The purpose is therefore not to use ML simply because it is more advanced, but to test whether a learned model provides useful decision support beyond a fixed rule.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ### Self-check
#
# - [x] Task type: Binary classification
# - [x] Target/proxy identified
# - [x] Success metric selected
# - [x] Unit of analysis identified
# - [x] Real dataframe shown
# - [ ] Final target threshold decided
# - [ ] Model trained and evaluated

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [x] Every section above is filled — markdown thinking AND the code that backs it
# - [x] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [x] No client names, URLs, or private queries anywhere
# - [x] My claims use careful words: observed, measured, directional, decision-support
# - [x] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
